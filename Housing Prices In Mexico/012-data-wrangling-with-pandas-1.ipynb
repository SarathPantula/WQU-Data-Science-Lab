# %%
import pandas as pd
from IPython.display import VimeoVideo

# %%
import pandas as pd

df1 = pd.read_csv("data/mexico-real-estate-1.csv")
df2 = pd.read_csv("data/mexico-real-estate-2.csv")
df3 = pd.read_csv("data/mexico-real-estate-3.csv")

df1
# Out:
#     property_type                            state        lat         lon  \
# 0           house                 Estado de México  19.560181  -99.233528
# 1           house                       Nuevo León  25.688436 -100.198807
# 2       apartment                         Guerrero  16.767704  -99.764383
# 3       apartment                         Guerrero  16.829782  -99.911012
# 4           house  Veracruz de Ignacio de la Llave        NaN         NaN
# ..            ...                              ...        ...         ...
# 695         house                          Morelos        NaN         NaN
# 696         house                          Yucatán  21.050653  -89.558841
# 697         house                          Yucatán  21.343796  -89.262060
# 698     apartment                       Nuevo León        NaN         NaN
# 699         house                        Querétaro  20.587378 -100.418361
#
#      area_m2    price_usd
# 0        150   $67,965.56
# ...

# %%
import pandas as pd

df1.shape
# Out:
# (700, 6)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  700 non-null    object
#  1   state          700 non-null    object
#  2   lat            583 non-null    float64
#  3   lon            583 non-null    float64
#  4   area_m2        700 non-null    int64
#  5   price_usd      700 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 32.9+ KB

# %%
df1.head()
# Out:
#   property_type                            state        lat         lon  \
# 0         house                 Estado de México  19.560181  -99.233528
# 1         house                       Nuevo León  25.688436 -100.198807
# 2     apartment                         Guerrero  16.767704  -99.764383
# 3     apartment                         Guerrero  16.829782  -99.911012
# 4         house  Veracruz de Ignacio de la Llave        NaN         NaN
#
#    area_m2   price_usd
# 0      150  $67,965.56
# 1      186  $63,223.78
# 2       82  $84,298.37
# 3      150  $94,308.80
# 4      175  $94,835.67

# %%
#Remove NAN vslues

df1.dropna(inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 583 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  583 non-null    object
#  1   state          583 non-null    object
#  2   lat            583 non-null    float64
#  3   lon            583 non-null    float64
#  4   area_m2        583 non-null    int64
#  5   price_usd      583 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 31.9+ KB

# %%
df1["price_usd"] = df1["price_usd"].str.replace("$","").str.replace(",","")
df1
# Out:
#     property_type             state        lat         lon  area_m2  price_usd
# 0           house  Estado de México  19.560181  -99.233528      150   67965.56
# 1           house        Nuevo León  25.688436 -100.198807      186   63223.78
# 2       apartment          Guerrero  16.767704  -99.764383       82   84298.37
# 3       apartment          Guerrero  16.829782  -99.911012      150   94308.80
# 5           house           Yucatán  21.052583  -89.538639      205  105191.37
# ..            ...               ...        ...         ...      ...        ...
# 693         house            Puebla  19.051815  -98.277669      198  115910.26
# 694     apartment  Distrito Federal  19.309208  -99.171906       70   77572.89
# 696         house           Yucatán  21.050653  -89.558841      334  137017.34
# 697         house           Yucatán  21.343796  -89.262060      130  110404.35
# 699         house         Querétaro  20.587378 -100.418361      106   56637.97
#
# [583 rows x 6 columns]

# %%
df1["price_usd"] = df1.price_usd.astype(float)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 583 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  583 non-null    object
#  1   state          583 non-null    object
#  2   lat            583 non-null    float64
#  3   lon            583 non-null    float64
#  4   area_m2        583 non-null    int64
#  5   price_usd      583 non-null    float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 31.9+ KB

# %%
df2.shape
# Out:
# (700, 6)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  700 non-null    object
#  1   state          700 non-null    object
#  2   lat            571 non-null    float64
#  3   lon            571 non-null    float64
#  4   area_m2        700 non-null    int64
#  5   price_mxn      700 non-null    int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 32.9+ KB

# %%
df2.dropna(inplace=True)
df2
# Out:
#     property_type             state        lat         lon  area_m2  price_mxn
# 0       apartment        Nuevo León  25.721081 -100.345581       72    1300000
# 2           house           Morelos  23.634501 -102.552788      360    5300000
# 6       apartment  Estado de México  19.272040  -99.572013       85    1250000
# 7           house   San Luis Potosí  22.138882 -100.996510      158    2120000
# 8       apartment  Distrito Federal  19.394558  -99.129707       65     758190
# ..            ...               ...        ...         ...      ...        ...
# 695         house           Morelos  18.917542  -98.963181      140    1450000
# 696         house  Distrito Federal  19.472128  -99.146697      190    1943000
# 697         house  Estado de México  19.234984  -99.558175      115    2100000
# 698         house            Puebla  18.918714  -98.426639       90     890000
# 699         house           Yucatán  21.075163  -89.516731      185    1695000
#
# [571 rows x 6 columns]

# %%
df2["price_usd"] = df2["price_mxn"]/19
df2.head()
# Out:
#   property_type             state        lat         lon  area_m2  price_mxn  \
# 0     apartment        Nuevo León  25.721081 -100.345581       72    1300000
# 2         house           Morelos  23.634501 -102.552788      360    5300000
# 6     apartment  Estado de México  19.272040  -99.572013       85    1250000
# 7         house   San Luis Potosí  22.138882 -100.996510      158    2120000
# 8     apartment  Distrito Federal  19.394558  -99.129707       65     758190
#
#        price_usd
# 0   68421.052632
# 2  278947.368421
# 6   65789.473684
# 7  111578.947368
# 8   39904.736842

# %%
df2 = df2.drop("price_mxn", axis="columns")
df2.head()
# Out:
#   property_type             state        lat         lon  area_m2  \
# 0     apartment        Nuevo León  25.721081 -100.345581       72
# 2         house           Morelos  23.634501 -102.552788      360
# 6     apartment  Estado de México  19.272040  -99.572013       85
# 7         house   San Luis Potosí  22.138882 -100.996510      158
# 8     apartment  Distrito Federal  19.394558  -99.129707       65
#
#        price_usd
# 0   68421.052632
# 2  278947.368421
# 6   65789.473684
# 7  111578.947368
# 8   39904.736842

# %%
df3.shape
# Out:
# (700, 5)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   property_type            700 non-null    object
#  1   place_with_parent_names  700 non-null    object
#  2   lat-lon                  582 non-null    object
#  3   area_m2                  700 non-null    int64
#  4   price_usd                700 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 27.5+ KB

# %%
df3.head()
# Out:
#   property_type                            place_with_parent_names  \
# 0     apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1         house           |México|Estado de México|Toluca|Metepec|
# 2         house  |México|Estado de México|Toluca|Toluca de Lerd...
# 3         house        |México|Morelos|Temixco|Burgos Bugambilias|
# 4     apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
#
#                   lat-lon  area_m2  price_usd
# 0     19.52589,-99.151703       71   48550.59
# 1  19.2640539,-99.5727534      233  168636.73
# 2    19.268629,-99.671722      300   86932.69
# 3                     NaN      275  263432.41
# 4    19.511938,-96.871956       84   68508.67

# %%
df3.dropna(inplace=True)
df3
# Out:
#     property_type                            place_with_parent_names  \
# 0       apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1           house           |México|Estado de México|Toluca|Metepec|
# 2           house  |México|Estado de México|Toluca|Toluca de Lerd...
# 4       apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
# 5           house                       |México|Jalisco|Guadalajara|
# ..            ...                                                ...
# 695         house  |México|Jalisco|Tlajomulco de Zúñiga|Tlajomulc...
# 696         house                          |México|Morelos|Jiutepec|
# 697         house                            |México|Yucatán|Mérida|
# 698         house           |México|San Luis Potosí|San Luis Potosí|
# 699         house           |México|Estado de México|Toluca|Metepec|
#
#                           lat-lon  area_m2  price_usd
# 0             19.52589,-99.151703       71   48550.59
# ...

# %%
df3[["lat", "lon"]] = df3["lat-lon"].str.split(",", expand=True)
df3.head()
# Out:
#   property_type                            place_with_parent_names  \
# 0     apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1         house           |México|Estado de México|Toluca|Metepec|
# 2         house  |México|Estado de México|Toluca|Toluca de Lerd...
# 4     apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
# 5         house                       |México|Jalisco|Guadalajara|
#
#                   lat-lon  area_m2  price_usd         lat          lon
# 0     19.52589,-99.151703       71   48550.59    19.52589   -99.151703
# 1  19.2640539,-99.5727534      233  168636.73  19.2640539  -99.5727534
# 2    19.268629,-99.671722      300   86932.69   19.268629   -99.671722
# 4    19.511938,-96.871956       84   68508.67   19.511938   -96.871956
# 5   20.689157,-103.366728      175  102763.00   20.689157  -103.366728

# %%
df3["state"] = df3["place_with_parent_names"].str.split("|", expand=True)[2]
df3
# Out:
#     property_type                            place_with_parent_names  \
# 0       apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1           house           |México|Estado de México|Toluca|Metepec|
# 2           house  |México|Estado de México|Toluca|Toluca de Lerd...
# 4       apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
# 5           house                       |México|Jalisco|Guadalajara|
# ..            ...                                                ...
# 695         house  |México|Jalisco|Tlajomulco de Zúñiga|Tlajomulc...
# 696         house                          |México|Morelos|Jiutepec|
# 697         house                            |México|Yucatán|Mérida|
# 698         house           |México|San Luis Potosí|San Luis Potosí|
# 699         house           |México|Estado de México|Toluca|Metepec|
#
#                           lat-lon  area_m2  price_usd            lat  \
# ...

# %%
cols_to_drop = ["place_with_parent_names", "lat-lon"]
print(df3.columns)
df3.drop(columns=[col for col in cols_to_drop if col in df3.columns], inplace=True)
df3.head()
# Out:
# Index(['property_type', 'place_with_parent_names', 'lat-lon', 'area_m2',
#        'price_usd', 'lat', 'lon', 'state'],
#       dtype='object')
#   property_type  area_m2  price_usd         lat          lon  \
# 0     apartment       71   48550.59    19.52589   -99.151703
# 1         house      233  168636.73  19.2640539  -99.5727534
# 2         house      300   86932.69   19.268629   -99.671722
# 4     apartment       84   68508.67   19.511938   -96.871956
# 5         house      175  102763.00   20.689157  -103.366728
#
#                              state
# 0                 Distrito Federal
# 1                 Estado de México
# 2                 Estado de México
# 4  Veracruz de Ignacio de la Llave
# 5                          Jalisco

# %%
df = pd.concat([df1, df2])
df = pd.concat([df, df3])

df
# Out:
#     property_type             state            lat              lon  area_m2  \
# 0           house  Estado de México      19.560181       -99.233528      150
# 1           house        Nuevo León      25.688436      -100.198807      186
# 2       apartment          Guerrero      16.767704       -99.764383       82
# 3       apartment          Guerrero      16.829782       -99.911012      150
# 5           house           Yucatán      21.052583       -89.538639      205
# ..            ...               ...            ...              ...      ...
# 695         house           Jalisco      20.532264      -103.484418      175
# 696         house           Morelos     18.9289862      -99.1802147      100
# 697         house           Yucatán  21.0284038368   -89.6530058049       81
# 698         house   San Luis Potosí    22.11830417  -101.0321938992      360
# 699         house  Estado de México      19.233201       -99.558519      115
#
#      price_usd
# 0     67965.56
# ...

# %%
df.to_csv("data/small-df.csv", index=False)
